# %%
import pandas as  pd
import numpy as np

# %%
df=pd.read_csv("census.csv")

# %%
df.head()
# Out:
#               Age                Eduation Marital_Status  Gender  \
# 0              73      Highschoolgraduate        Widowed  Female
# 1              58  Somecollegebutnodegree       Divorced    Male
# 2              18               10thgrade   Nevermarried  Female
# 3               9                Children   Nevermarried  Female
# 4              10                Children   Nevermarried  Female
#
#   Tax_Filing_Status   Income      Parents_Status Country_of_Birth  \
# 0          Nonfiler  1700.09       Notinuniverse    United-States
# 1   Headofhousehold  1053.55       Notinuniverse    United-States
# 2          Nonfiler   991.95       Notinuniverse          Vietnam
# 3          Nonfiler  1758.14  Bothparentspresent    United-States
# 4          Nonfiler  1069.16  Bothparentspresent    United-States
#
#                 Nativity status  Weeks_worked
# 0  Native-BornintheUnitedStates             0
# 1  Native-BornintheUnitedStates            52
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0              Age     2000 non-null   int64
#  1   Eduation           2000 non-null   object
#  2   Marital_Status     2000 non-null   object
#  3   Gender             2000 non-null   object
#  4   Tax_Filing_Status  2000 non-null   object
#  5   Income             2000 non-null   float64
#  6   Parents_Status     2000 non-null   object
#  7   Country_of_Birth   2000 non-null   object
#  8    Nativity status   2000 non-null   object
#  9   Weeks_worked       2000 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 156.4+ KB
