# %%
import  pandas as pd

# %%
data=pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    Age  InsuranceCost
# 0   22           2500
# 1   25           2800
# 2   28           3200
# 3   30           3500
# 4   35           4200

# %%
x=data['Age']
x
# Out:
# 0    22
# 1    25
# 2    28
# 3    30
# 4    35
# 5    40
# 6    45
# 7    50
# 8    55
# 9    60
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(data['Age'],data['InsuranceCost'])

m,c=np.polyfit(data['Age'],data['InsuranceCost'],1)

plt.plot(x,m*data['Age']+c)

# m is slope

# %%
import seaborn as sns
sns.regplot(x='Age',y='InsuranceCost',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='InsuranceCost'>

# %%
x=data['Age']
y=data['InsuranceCost']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2)

# %%
print("---------x_train----------")
print(x_train)
print("----------y_train---------")
print(y_train)

print("----------x_test---------")
print(x_test)
# Out:
# ---------x_train----------
# 4    35
# 1    25
# 3    30
# 8    55
# 5    40
# 9    60
# 6    45
# 2    28
# Name: Age, dtype: int64
# ----------y_train---------
# 4    4200
# 1    2800
# 3    3500
# 8    7200
# 5    5000
# 9    8000
# 6    5800
# 2    3200
# Name: InsuranceCost, dtype: int64
# ----------x_test---------
# 7    50
# 0    22
# Name: Age, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train)
model.predict([[30]])
# Out:
# array([3508.52645387])

# %%
y_pred=model.predict(x_test.values.reshape(-1,1))
y_pred
# Out:
# array([6491.03629209, 2315.52251858])

# %%
plt.scatter(x_test,y_test,color='blue')
m,c=np.polyfit(x_test,y_test,1)

plt.plot(x_test,m*x_test+c)
