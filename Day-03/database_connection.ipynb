# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.5 MB 798.2 kB/s eta 0:00:21
#    - -------------------------------------- 0.5/16.5 MB 798.2 kB/s eta 0:00:21
#    - -------------------------------------- 0.8/16.5 MB 857.8 kB/s eta 0:00:19
#    - -------------------------------------- 0.8/16.5 MB 857.8 kB/s eta 0:00:19
#    -- ------------------------------------- 1.0/16.5 MB 780.3 kB/s eta 0:00:20
#    -- ------------------------------------- 1.0/16.5 MB 780.3 kB/s eta 0:00:20
# ...

# %%
from mysql import connector

# %%
##Step2: Establish a connection to the MySQL database

# %%
conn=connector.connect(
    host="localhost",
    user="root",
    password="1644",   
)
print("connection established:",conn.is_connected())
# Out:
# connection established: True

# %%
cursor=conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS Student_db")
print("Database created successfully")
# Out:
# Database created successfully

# %%
conn=connector.connect(
    host="localhost",
    user="root",
    password="1644",  
    database="Student_db", 
)
cursor=conn.cursor()
print("Connected to database:",conn.is_connected())
# Out:
# Connected to database: True

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS Students (id INT AUTO_INCREMENT PRIMARY KEY,name VARCHAR(255),age INT)")
print("Table created successfully")
# Out:
# Table created successfully

# %%
cursor.execute("insert into Students values(1,'Arun',19)")
print("Record inserted successfully")
# Out:
# Record inserted successfully

# %%
cursor.execute("INSERT INTO Students VALUES (2, 'vaibhav', 20)")
cursor.execute("INSERT INTO Students VALUES (3, 'sreehas', 21)")

print("Multiple records inserted successfully")
# Out:
# Multiple records inserted successfully

# %%
query = "INSERT INTO Students VALUES (%s, %s, %s)"
values = [
    (4, 'Rahul', 20),
    (5, 'Anita', 22),
    (6, 'Kiran', 19)
]

cursor.fetchall()     
cursor.executemany(query, values)
conn.commit()

print("Successfully inserted")
# Out:
# Successfully inserted

# %%
cursor.execute("SELECT * from Students")
records=cursor.fetchall()
for row in records:
    print(row)
# Out:
# (1, 'Arun', 19)
# (2, 'vaibhav', 20)
# (3, 'sreehas', 21)
# (4, 'Rahul', 20)
# (5, 'Anita', 22)
# (6, 'Kiran', 19)
