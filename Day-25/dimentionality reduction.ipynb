# %% [markdown]
# # Dimentionality Reduction

# %% [markdown]
# can i represent data with fewer features while keppimg maximum info

# %% [markdown]
# To achieve this concept:
# 1 feature Engineering  (feature selection)
# 2 feature Extraction.        input --500 --

# %% [markdown]
# 1. why do we need to reduse features
#  - too many features ----slow models
#  - hard to visualize for data
#  - reduse (irrelavent features)

# %%
import pandas as pd
data = {
    "Hours_Studied": [2, 4, 6, 8, 10, 3, 7],
    "Attendance": [60, 65, 70, 80, 90, 55, 75],
    "Projects": [0, 1, 2, 3, 4, 0, 2],
    "Internships": [0, 0, 1, 1, 2, 0, 1],
    "Certifications": [0, 1, 1, 2, 3, 0, 2],
    "CGPA": [5.5, 6.0, 7.0, 8.0, 8.5, 5.0, 7.5],
    "Placed": [0, 0, 1, 1, 1, 0, 1]
}
data = pd.DataFrame(data)
data
# Out:
#    Hours_Studied  Attendance  Projects  Internships  Certifications  CGPA  \
# 0              2          60         0            0               0   5.5
# 1              4          65         1            0               1   6.0
# 2              6          70         2            1               1   7.0
# 3              8          80         3            1               2   8.0
# 4             10          90         4            2               3   8.5
# 5              3          55         0            0               0   5.0
# 6              7          75         2            1               2   7.5
#
#    Placed
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
# 5       0
# 6       1

# %%
data.corr()
# Out:
#                 Hours_Studied  Attendance  Projects  Internships  \
# Hours_Studied        1.000000    0.970546  0.987002     0.954719
# Attendance           0.970546    1.000000  0.983847     0.940875
# Projects             0.987002    0.983847  1.000000     0.947421
# Internships          0.954719    0.940875  0.947421     1.000000
# Certifications       0.969178    0.976554  0.958317     0.905822
# CGPA                 0.972140    0.981556  0.977822     0.931746
# Placed               0.884598    0.831624  0.863462     0.883883
#
#                 Certifications      CGPA    Placed
# Hours_Studied         0.969178  0.972140  0.884598
# Attendance            0.976554  0.981556  0.831624
# Projects              0.958317  0.977822  0.863462
# Internships           0.905822  0.931746  0.883883
# Certifications        1.000000  0.957611  0.800641
# CGPA                  0.957611  1.000000  0.912245
# Placed                0.800641  0.912245  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.scatter(data["Hours_Studied"], data["CGPA"])

# %%
import pandas as pd
data = pd.DataFrame({
    "math": [85, 90, 78, 92, 88],
    "physics": [80, 85, 78, 90, 88]
})
data
# Out:
#    math  physics
# 0    85       80
# 1    90       85
# 2    78       78
# 3    92       90
# 4    88       88

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
model = PCA(n_components=1)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
x_PCA = model.fit_transform(scaled_data).flatten()
x_PCA


I=[1,2,3,4,5]
plt.scatter(x_PCA, [0]*len(x_PCA))
